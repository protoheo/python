# %%
# coding: utf-8# codin 
import pandas as pd
import numpy as np
from matplotlib import rcParams
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import networkx as nx
from datetime import datetime
from PIL import Image
from os import path
import matplotlib.patches as mpatches
import random
import callDB as cd

# %matplotlib inline  

sns.set(style="whitegrid", palette="colorblind", color_codes=True, font_scale=1.4,
        rc = {'font.size': 12, 'font.family':'NanumBarunGothic'})

# %%
col_pal = "#C4D4E0 #9AABB9 #E2B49A #E9C77B #193446 #E5DACE #B2B2A2 #6D7973 #3F3931".split()
sns.palplot(col_pal)

# %%
log_in_documents = cd.readDB()
log_out_documents = cd.readDB2()

# %%
dd=pd.DataFrame(log_in_documents)
type(dd[5])
# Out:
# pandas.core.series.Series

# %%
def makeVisualizationTable(document_table, official_doc_status):
    return_processed_table = []
    cnt = 0
    for i, row in enumerate(document_table):
        if(row[5] != None):
            return_processed_table.append([])
            #return_processed_table[cnt].append(row[0])               # No.
            return_processed_table[cnt].append(official_doc_status)  # Status
            return_processed_table[cnt].append(row[1])               # Document Code
            return_processed_table[cnt].append(row[2])               # Document Title
            return_processed_table[cnt].append(row[3])               # Issue From
            return_processed_table[cnt].append(row[4])               # Issue Timedelta
            return_processed_table[cnt].append(int(row[5][:4]))           # Issue Year
            return_processed_table[cnt].append(int(row[5][5:7]))          # Issue Month
            return_processed_table[cnt].append(int(row[5][8:10]))         # Issue Day            
            return_processed_table[cnt].append(row[7])               # Responsed Document
            return_processed_table[cnt].append(row[8])               # Response Timedelta
            if(row[9] != None):
                return_processed_table[cnt].append(int(row[9][:4]))       # Issue Year
                return_processed_table[cnt].append(int(row[9][5:7]))      # Issue Month
                return_processed_table[cnt].append(int(row[9][8:10]))     # Issue Day
            else:
                return_processed_table[cnt].append(None)
                return_processed_table[cnt].append(None)
                return_processed_table[cnt].append(None)
            cnt += 1

    return return_processed_table

# %%
in_table = makeVisualizationTable(log_in_documents,"In")
out_table = makeVisualizationTable(log_out_documents,"Out")
total_table = in_table+out_table

# %%
cols = ["Status", "Document_Code", "Document_Title", "Issue_From", "Issue_Timedelta",
       "Issue_Year", "Issue_Month", "Issue_Day", "Responsed_Document", "Response_Timedelta",
       "Response_Year", "Response_Month", "Response_Day"]
dataframe_total=pd.DataFrame(total_table, columns=cols)
dataframe_total=dataframe_total.sort_values(by='Issue_Timedelta').reset_index(drop=True)

# %%
dataframe_total['days'] = dataframe_total['Issue_Timedelta'].apply(lambda x : int(x-dataframe_total['Issue_Timedelta'].min()))
dataframe_total['total']=' '

# %%
plt.figure(figsize=(15,9))
sns.set(style="whitegrid", palette="colorblind", color_codes=True, font_scale=1.4,
        rc = {'font.size': 12, 'font.family':'NanumBarunGothic'})
sns.violinplot(data=dataframe_total, x='days', y='total', hue='Status',split=True, 
               orient='h', width=.8,  cut=2, bw=.1, scale='count', colors=col_pal)
## draw x-ticks
ticks = dataframe_total.groupby("Issue_Year").min()[["days"]]
#plt.xlim(0,1900)
xticks = plt.xticks( ticks.days.tolist(), [ "%d년" % m for m in ticks.index.tolist()] )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# 1. dd
# 2. dd
# 3. dff

# %%
dataframe_total
# Out:
#       Status                  Document_Code  \
# 0         In        MRPSC/015/10-11/2080/11
# 1         In        MRPSC/015/10-11/2423/11
# 2         In           MRPSC/015/10-11/3496
# 3         In           MRPSC/015/10-11/4247
# 4         In  DXW-P003-0000-CP-KBR-LT-01146
# 5         In  EXW-P003-0000-CP-KBR-LT-01409
# 6        Out               Doha JS-2011-771
# 7         In        MRPSC/015/10-11/7363/11
# 8        Out               Doha JS-2011-889
# 9         In              MRPSC/022/01/2012
# 10       Out               Doha JS-2012-021
# 11       Out               Doha JS-2012-048
# 12        In              MRPSC/047/01/2012
# 13        In
# 14       Out               Doha JS-2012-066
# 15       Out               Doha JS-2012-082
# 16       Out               Doha JS-2012-088
# 17        In              MRPSC/053/02/2012
# 18       Out               Doha JS-2012-100
# 19        In  EXW-P003-0000-PE-KBR-LT-02524
# 20       Out               Doha JS-2012-150
# 21       Out             Doha JS-2012-17977
# 22        In  EXW-P003-0000-CP-KBR-LT-02890
# 23       Out               Doha JS-2012-218
# 24       Out               Doha JS-2012-241
# 25       Out               Doha JS-2012-240
# 26       Out               Doha JS-2012-253
# 27        In              MRPSC/111/03/2012
# 28        In
# 29       Out               Doha JS-2012-308
# ...      ...                            ...
# 16975     In  EXW-P003-0000-CP-CDM-LT-21300
# 16976     In  EXW-P003-0000-CP-CDM-LT-21295
# 16977     In  EXW-P003-0000-HS-CDM-SV-02046
# 16978     In  EXW-P003-0000-HS-CDM-SV-02045
# 16979     In  EXW-P003-0000-TM-CDM-LT-21313
# 16980     In  EXW-P003-0000-CP-CDM-LT-21310
# 16981     In  EXW-P003-0000-CP-CDM-LT-21304
# 16982     In  EXW-P003-0000-CP-CDM-LT-21294
# 16983     In  EXW-P003-0000-CP-CDM-LT-21296
# 16984    Out  EXW-P003-0000-EE-HYI-LT-06065
# 16985    Out  EXW-P003-0000-PM-HYI-LT-06066
# 16986    Out  EXW-P003-0100-PC-HYI-LT-06067
# 16987    Out  EXW-P003-0000-PC-HYI-LT-06068
# 16988     In  EXW-P003-0000-HS-CDM-SV-16711
# 16989     In     QDVC/005/ DIB/ 2017/ 24736
# 16990     In  EXW-GENL-0000-QM-KBR-ME-80551
# 16991     In  EXW-P003-0000-CP-CDM-LT-21297
# 16992     In  EXW-P003-0000-EE-CDM-LT-21315
# 16993     In  EXW-P003-0000-RW-CDM-LT-21316
# 16994     In  EXW-P003-0000-EE-CDM-LT-21321
# 16995     In  EXW-P003-0000-CM-CDM-LT-21322
# 16996     In  EXW-P003-0000-QM-CDM-LT-21323
# 16997     In  EXW-P003-0100-CP-CDM-LT-21326
# 16998     In  EXW-P003-0000-TM-CDM-RM-15343
# 16999     In  EXW-P003-0000-TM-CDM-RM-15344
# 17000     In  EXW-P003-0000-TM-CDM-RM-15345
# 17001     In  EXW-P003-0000-TM-CDM-RM-15346
# 17002    Out  EXW-P003-0000-CP-HYI-CP-06070
# 17003    Out  EXW-P003-0000-PM-HYI-CP-06071
# 17004    Out  EXW-P003-0000-PM-HYI-LT-06072
#
#                                           Document_Title Issue_From  \
# 0                                   Invitation to Tender    ASHGHAL
# 1                               Response to Tender Query    ASHGHAL
# 2                                 Tender Submission Date    ASHGHAL
# 3                Tender Submission Date(Final Extension)    ASHGHAL
# 4                                    Tender Presentation        KBR
# 5      Post Tender Clarification for Reconstruction a...        KBR
# 6      Post Tender Clarification for Reconstruction a...    ASHGHAL
# 7                                Financial Clarification    ASHGHAL
# 8                 Clarifications on Financial Submission    ASHGHAL
# 9                                Financial Clarification    ASHGHAL
# 10                Clarifications on Financial Submission    ASHGHAL
# 11     Contribution  of a certain value to the countr...    ASHGHAL
# 12     Extension of Tender Validity and Validity of t...    ASHGHAL
# 13     Discuss Artscape design / Construction procure...    ASHGHAL
# 14                  Request for re-arranging the meeting    ASHGHAL
# 15      Proposal for the Artscape Design and Procurement    ASHGHAL
# 16      Proposal for the Artscape Design and Procurement    ASHGHAL
# 17           Proposal of Artscape Design and Procurement    ASHGHAL
# 18     Reply to Proposal for the Artscape Design and ...    ASHGHAL
# 19                           Transmittal of Information         KBR
# 20      Proposal for the Artscape Design and Procurement    ASHGHAL
# 21     Revised Proposal for Artscape Design and Procu...    ASHGHAL
# 22          Proposal for Artscape Design and Procurement        KBR
# 23          Proposal for Artscape Design and Procurement        KBR
# 24      Proposal for the Artscape Design and Procurement    ASHGHAL
# 25      Proposal for the Artscape Design and Procurement    ASHGHAL
# 26                       Confirmation of Letter of Award    ASHGHAL
# 27                                       Awarding Letter    ASHGHAL
# 28                              Advance Kick-Off Meeting        KBR
# 29                    Request for Ashghal's Instructions    ASHGHAL
# ...                                                  ...        ...
# 16975  Claim No. 36 - Sewage House Re-Connection in f...        CDM
# 16976  Entitlement to Additional Costs for Mass Concr...        CDM
# 16977                  Safety Violation Report No. 02046        CDM
# 16978                  Safety Violation Report No. 02045        CDM
# 16979                  Pearl / Katara Traffic Diversions        CDM
# 16980                            Clause 52, Claim No. 16        CDM
# 16981  Site Instruction No. 165 Cost Implication: Rem...        CDM
# 16982                          Outstanding Claims Status        CDM
# 16983  Qatar Embargo: Closure of Borders, Travel and ...        CDM
# 16984    Temporary CCTV, PA and ERT in PT2 & PT3 Tunnels        CDM
# 16985  Diplomatic Dispute - Closed Borders: Delay Mit...        CDM
# 16986           Artscape - Weekly Rolling Program No. 93        CDM
# 16987  Undertaking and Compliance Forms for Cables - ...        CDM
# 16988                   Safety Issue Report 30 July 2017        CDM
# 16989  LRT/ Metro Legtaifiya Station - Request for NO...       QDVC
# 16990               Updated Approved Asphalt Mixes List         KBR
# 16991                                           Payments        CDM
# 16992  SW4A Works for Existing Pump Room, Existing Pu...        CDM
# 16993  Q-Rail Overview Drawings and Network Schemes S...        CDM
# 16994  MME Building Permits for Pearl Substations Nos...        CDM
# 16995  LRT Tunnel - Water Leakage Inside Tunnel and C...        CDM
# 16996  Updated List of Approved Tests & Labs used in ...        CDM
# 16997  Artscape - Additional Submission of Pre-Qualif...        CDM
# 16998  Traffic Management Monthly Inspection -Stage -...        CDM
# 16999  Traffic Management Monthly Inspection -Stage -...        CDM
# 17000  Traffic Management Monthly Inspection -Stage -...        CDM
# 17001  Traffic Management Monthly Inspection -Stage -...        CDM
# 17002  Notice Under Contract Clause 44 - Artscape: Ex...        CDM
# 17003  Artscape - Commercial Report for MEP Works of ...        CDM
# 17004            Delay in Return of Site from El Sewedy   ELSEWEDY
#
#        Issue_Timedelta  Issue_Year Issue_Month Issue_Day  \
# 0              40591.0        2011          02        17
# 1              40603.0        2011          03        01
# 2              40654.0        2011          04        21
# 3              40701.0        2011          06        07
# 4              40797.0        2011          09        11
# 5              40828.0        2011          10        12
# 6              40836.0        2011          10        20
# 7              40897.0        2011          12        20
# 8              40898.0        2011          12        21
# 9              40916.0        2012          01        08
# 10             40919.0        2012          01        11
# 11             40929.0        2012          01        21
# 12             40934.0        2012          01        26
# 13             40936.0        2012          01        28
# 14             40937.0        2012          01        29
# 15             40941.0        2012          02        02
# 16             40942.0        2012          02        03
# 17             40946.0        2012          02        07
# 18             40951.0        2012          02        12
# 19             40957.0        2012          02        18
# 20             40961.0        2012          02        22
# 21             40969.0        2012          03        01
# 22             40981.0        2012          03        13
# 23             40981.0        2012          03        13
# 24             40987.0        2012          03        19
# 25             40987.0        2012          03        19
# 26             40990.0        2012          03        22
# 27             40990.0        2012          03        22
# 28             41003.0        2012          04        04
# 29             41003.0        2012          04        04
# ...                ...         ...         ...       ...
# 16975          42946.0        2017          07        30
# 16976          42946.0        2017          07        30
# 16977          42946.0        2017          07        30
# 16978          42946.0        2017          07        30
# 16979          42946.0        2017          07        30
# 16980          42946.0        2017          07        30
# 16981          42946.0        2017          07        30
# 16982          42946.0        2017          07        30
# 16983          42946.0        2017          07        30
# 16984          42947.0        2017          07        31
# 16985          42947.0        2017          07        31
# 16986          42947.0        2017          07        31
# 16987          42947.0        2017          07        31
# 16988          42947.0        2017          07        31
# 16989          42947.0        2017          07        31
# 16990          42947.0        2017          07        31
# 16991          42947.0        2017          07        31
# 16992          42947.0        2017          07        31
# 16993          42947.0        2017          07        31
# 16994          42947.0        2017          07        31
# 16995          42947.0        2017          07        31
# 16996          42947.0        2017          07        31
# 16997          42947.0        2017          07        31
# 16998          42947.0        2017          07        31
# 16999          42947.0        2017          07        31
# 17000          42947.0        2017          07        31
# 17001          42947.0        2017          07        31
# 17002          42948.0        2017          08        01
# 17003          42948.0        2017          08        01
# 17004          42948.0        2017          08        01
#
#                   Responsed_Document Response_Timedelta Response_Year  \
# 0                                                                None
# 1                                                                None
# 2                                                                None
# 3                                                                None
# 4                                                                None
# 5                   DOHA JS-2011-771              40836          2011
# 6                                                                None
# 7                                                                None
# 8                                                                None
# 9                                                                None
# 10                                                               None
# 11                                                               None
# 12                                                               None
# 13                                                               None
# 14                                                               None
# 15                                                               None
# 16                                                               None
# 17                                                               None
# 18                                                               None
# 19     EXW-P003-0000-PE-HYI-LT-02278              41776          2014
# 20                                                               None
# 21     EXW-P003-0000-CP-KBR-LT-02890              40981          2012
# 22     EXW-P003-0000-AF-HYI-LT-00112              41111          2012
# 23                                                               None
# 24                                                               None
# 25                                                               None
# 26                                                               None
# 27                                                               None
# 28                                                               None
# 29                                                               None
# ...                              ...                ...           ...
# 16975                                                            None
# 16976                                                            None
# 16977                                                            None
# 16978                                                            None
# 16979                                                            None
# 16980                                                            None
# 16981                                                            None
# 16982                                                            None
# 16983                                                            None
# 16984                                                            None
# 16985                                                            None
# 16986                                                            None
# 16987                                                            None
# 16988                                                            None
# 16989                                                            None
# 16990                                                            None
# 16991                                                            None
# 16992                                                            None
# 16993                                                            None
# 16994                                                            None
# 16995                                                            None
# 16996                                                            None
# 16997                                                            None
# 16998                                                            None
# 16999                                                            None
# 17000                                                            None
# 17001                                                            None
# 17002                                                            None
# 17003                                                            None
# 17004                                                            None
#
#       Response_Month Response_Day  days total
# 0               None         None     0
# 1               None         None    12
# 2               None         None    63
# 3               None         None   110
# 4               None         None   206
# 5                 10           20   237
# 6               None         None   245
# 7               None         None   306
# 8               None         None   307
# 9               None         None   325
# 10              None         None   328
# 11              None         None   338
# 12              None         None   343
# 13              None         None   345
# 14              None         None   346
# 15              None         None   350
# 16              None         None   351
# 17              None         None   355
# 18              None         None   360
# 19                05           17   366
# 20              None         None   370
# 21                03           13   378
# 22                07           21   390
# 23              None         None   390
# 24              None         None   396
# 25              None         None   396
# 26              None         None   399
# 27              None         None   399
# 28              None         None   412
# 29              None         None   412
# ...              ...          ...   ...   ...
# 16975           None         None  2355
# 16976           None         None  2355
# 16977           None         None  2355
# 16978           None         None  2355
# 16979           None         None  2355
# 16980           None         None  2355
# 16981           None         None  2355
# 16982           None         None  2355
# 16983           None         None  2355
# 16984           None         None  2356
# 16985           None         None  2356
# 16986           None         None  2356
# 16987           None         None  2356
# 16988           None         None  2356
# 16989           None         None  2356
# 16990           None         None  2356
# 16991           None         None  2356
# 16992           None         None  2356
# 16993           None         None  2356
# 16994           None         None  2356
# 16995           None         None  2356
# 16996           None         None  2356
# 16997           None         None  2356
# 16998           None         None  2356
# 16999           None         None  2356
# 17000           None         None  2356
# 17001           None         None  2356
# 17002           None         None  2357
# 17003           None         None  2357
# 17004           None         None  2357
#
# [17005 rows x 15 columns]

# %%
import math

replace_chars = ":_![]/()'\",-&"
exclude_words = set(('safety', 'report', 'at', 'c', 'not', 'or', 'its', 'by', 'a', 'with', 'for',
                     'of', 'no', 'and', 'the', 'in', 'on', 'to', 'no.', '2014', '2015', '2016', '2017', '2013', '2012'))


def tokenize(string):
    string = string.lower()
    for ch in replace_chars:
        string = string.replace(ch, ' ')
    words = [word for word in string.split()
             if (word not in exclude_words) and (len(word) > 1) and (not word[0].isnumeric())
             ]
    return words


def group_func(x):    
    return '%d-%02d' % (x.Issue_Year, math.floor((x.Issue_Month-1)/3)*3)


def makeCorpus(ds, target):
    corpus = []
    idx2name = []

    for (name, group) in ds.groupby(ds.apply(group_func)):
        group_corpus = []
        for string in group[target].values:
            group_corpus.extend(tokenize(string))
        corpus.append(group_corpus)
        idx2name.append(name)
    return (corpus, idx2name)

# %%
dataframe_total['Document_Title'].values
# Out:
# array(['Invitation to Tender', 'Response to Tender Query',
#        'Tender Submission Date', ...,
#        'Notice Under Contract Clause 44 - Artscape: External Works Package',
#        'Artscape - Commercial Report for MEP Works of Al Wahda Arch',
#        'Delay in Return of Site from El Sewedy '], dtype=object)

# %%
(subject_corpus, idx2group) = makeCorpus(dataframe_total, 'Document_Title')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-dbae0d8d472c> in <module>()
# ----> 1 (subject_corpus, idx2group) = makeCorpus(dataframe_total, 'Document_Title')
#
# <ipython-input-71-e5444d774290> in makeCorpus(ds, target)
#      24     idx2name = []
#      25
# ---> 26     for (name, group) in ds.groupby(ds.apply(group_func)):
#      27         group_corpus = []
#      28         for string in group[target].values:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-71-e5444d774290> in group_func(x)
#      17
#      18 def group_func(x):
# ---> 19     return '%d-%02d' % (x.Issue_Year, math.floor((x.Issue_Month-1)/3)*3)
#      20
#      21
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: ("'Series' object has no attribute 'Issue_Year'", 'occurred at index Status')

# %%
from gensim import corpora, models, similarities
from time import time
import operator

dictionary = corpora.Dictionary(subject_corpus)

# compile corpus (vectors number of times each elements appears)
raw_corpus = [dictionary.doc2bow(t) for t in subject_corpus]

# Transform Text with TF-IDF
tfidf = models.TfidfModel(raw_corpus)  # step 1 -- initialize a model
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-350614b7b453> in <module>()
#       3 import operator
#       4
# ----> 5 dictionary = corpora.Dictionary(subject_corpus)
#       6
#       7 # compile corpus (vectors number of times each elements appears)
#
# NameError: name 'subject_corpus' is not defined

# %%
topic_word_list = []
topic_score_list = []
topic_word_count = 100

for (idx, src_name) in enumerate(idx2group):
    topic = tfidf[raw_corpus[idx]]
    src_name = src_name.lower()
    topic = [ (dictionary[word], score) for (word,score) in topic ]
    topic = sorted(topic, key=operator.itemgetter(1), reverse=True)
    
    topic_word_list.append( [ word for word, score in topic[:topic_word_count]] )
    topic_score_list.append( [ score for word, score in topic[:topic_word_count]] )

# %%
topic_score_ds = pd.DataFrame( topic_score_list, index=idx2group )
topic_score_ds.fillna(0, inplace=True)
topic_word_ds = pd.DataFrame( topic_word_list, index=idx2group )
topic_word_ds.fillna('', inplace=True)

## cut letters to 10
topic_word_ds = topic_word_ds.applymap(lambda x: x[:10])

# %%
sns.set(style="whitegrid", palette="colorblind", color_codes=True, font_scale=1.1, font='NanumBarunGothic' )
plt.figure(figsize=(18,14))
ax = sns.heatmap(topic_score_ds.ix[:,:10], annot=topic_word_ds.ix[:,:10].values, fmt="", linewidths=.2)
